# %% [markdown]
# # Fazendo seu código dar um Loop

# %% [markdown]
# O termo looping refere-se a repetir, várias vezes, um bloco de declarações em Python. Nesta seção, vamos explicar sobre os vários tipos diferentes de loops.
# Em Python, temos os loops for e while.
#
# for: opera sobre os itens de qualquer tipo de sequência (lista ou string) na ordem que aparecem.
#
# while: usado quando precisamos repetir uma ação algumas vezes ou fazer uma iteração até que uma condição seja satisfeita.

# %% [markdown]
# # Loop FOR

# %% [markdown]
# A estrutura de repetição for pode atuar sobre itens de qualquer tipo de sequência (lista ou string) na ordem em que aparecem.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Exemplo 01 – For simples

# %%
frutas = ["abacate", "pera", "abacaxi"]
for fruta in frutas:
    print (fruta)
# Out:
# abacate
# pera
# abacaxi

# %% [markdown]
# ##### Exemplo 02 – For e condicional

# %%
frutas = ["abacate", "pera", "abacaxi"]
for fruta in frutas:
    if fruta.startswith ("a"):
        print (fruta)
# Out:
# abacate
# abacaxi

# %% [markdown]
# ##### Exemplo 03 – For acumulador

# %%
listaNumeros = [1,2,3,4,5]
soma = 0
for numero in listaNumeros:
    soma = soma + numero
print(soma)
# Out:
# 15

# %% [markdown]
# # Loop While

# %% [markdown]
# A estrutura de repetição while é utilizada quando precisamos repetir uma ação algumas vezes ou fazer uma iteração até que uma condição seja satisfeita.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Exemplo 01

# %%
condicao = 1
soma = 0
while condicao <= 5:
    soma = soma + condicao
    condicao = condicao + 1
print (soma)
# Out:
# 15

# %% [markdown]
# ##### Exemplo 02

# %%
condicao = 5
soma = 0
while condicao >= 0:
    soma = soma + condicao
    condicao = condicao - 1
print (soma)
# Out:
# 15
